# %% [markdown]
# #Medallion Architecture pipeline (Bronze → Silver → Gold)

# %% [markdown]
# ##Download & Store CSV in DBFS

# %%
import requests
csv_url = "https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/Restaurant%20customer%20data.csv"
local_path = "/tmp/restaurant_data.csv"
dbfs_path = "dbfs:/mnt/raw_data/restaurant_data.csv"

# Download CSV file
response = requests.get(csv_url)
with open(local_path, "wb") as f:
    f.write(response.content)

# Move file to DBFS
dbutils.fs.mv(f"file://{local_path}", dbfs_path)

print("✅ File successfully stored in DBFS")
# Out:
# ✅ File successfully stored in DBFS

# %% [markdown]
# ##Ingest Data into the Bronze Layer (Raw Data)

# %%
from pyspark.sql import SparkSession

# Initialize Spark Session
spark = SparkSession.builder.appName("AutoLoaderMedallion").getOrCreate()

# Load raw data using Auto Loader
df_bronze = spark.readStream.format("cloudFiles") \
    .option("cloudFiles.format", "csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .option("cloudFiles.schemaLocation", "dbfs:/mnt/schema/") \
    .load("dbfs:/mnt/raw_data/")

# Save to Delta Lake (Bronze Table)
df_bronze.writeStream.format("delta") \
    .option("checkpointLocation", "dbfs:/mnt/checkpoints/bronze/") \
    .start("dbfs:/mnt/bronze_table")

print("✅ Data loaded into Bronze layer")
# Out:
# ✅ Data loaded into Bronze layer

# %%
display(df_bronze)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userID</th><th>latitude</th><th>longitude</th><th>smoker</th><th>drink_level</th><th>dress_preference</th><th>ambience</th><th>transport</th><th>marital_status</th><th>hijos</th><th>birth_year</th><th>interest</th><th>personality</th><th>religion</th><th>activity</th><th>color</th><th>weight</th><th>budget</th><th>height</th><th>_rescued_data</th></tr></thead><tbody><tr><td>U1001</td><td>22.139997</td><td>-100.978803</td><td>false</td><td>abstemious</td><td>informal</td><td>family</td><td>on foot</td><td>single</td><td>independent</td><td>1989</td><td>variety</td><td>thrifty-protector</td><td>none</td><td>student</td><td>black</td><td>69</td><td>medium</td><td>1.77</td><td>null</td></tr><tr><td>U1002</td><td>22.150087</td><td>-100.983325</td><td>false</td><td>abstemious</td><td>informal</td><td>family</td><td>public</td><td>single</td><td>independent</td><td>1990</td><td>technology</td><td>hunter-ostentatious</td><td>Catholic</td><td>student</td><td>red</td><td>40</td><td>low</td><td>1.87</td><td>null</td></tr><tr><td>U1003</td><td>22.119847</td><td>-100.946527</td><td>false</td><td>social drinker</td><td>formal</td><td>family</td><td>public</td><td>single</td><td>independent</td><td>1989</td><td>none</td><td>hard-worker</td><td>Catholic</td><td>student</td><td>blue</td><td>60</td><td>low</td><td>1.69</td><td>null</td></tr><tr><td>U1004</td><td>18.867</td><td>-99.183</td><td>false</td><td>abstemious</td><td>informal</td><td>family</td><td>public</td><td>single</td><td>independent</td><td>1940</td><td>variety</td><td>hard-worker</td><td>none</td><td>professional</td><td>green</td><td>44</td><td>medium</td><td>1.53</td><td>null</td></tr><tr><td>U1005</td><td>22.183477</td><td>-100.959891</td><td>false</td><td>abstemious</td><td>no preference</td><td>family</td><td>public</td><td>single</td><td>independent</td><td>1992</td><td>none</td><td>thrifty-protector</td><td>Catholic</td><td>student</td><td>black</td><td>65</td><td>medium</td><td>1.69</td><td>null</td></tr><tr><td>U1006</td><td>22.15</td><td>-100.983</td><td>true</td><td>social drinker</td><td>no preference</td><td>friends</td><td>car owner</td><td>single</td><td>independent</td><td>1989</td><td>variety</td><td>hard-worker</td><td>none</td><td>student</td><td>blue</td><td>75</td><td>medium</td><td>1.8</td><td>null</td></tr><tr><td>U1007</td><td>22.118464</td><td>-100.938256</td><td>false</td><td>casual drinker</td><td>informal</td><td>solitary</td><td>public</td><td>single</td><td>independent</td><td>1989</td><td>variety</td><td>thrifty-protector</td><td>Catholic</td><td>student</td><td>purple</td><td>60</td><td>low</td><td>1.59</td><td>null</td></tr><tr><td>U1008</td><td>22.122989</td><td>-100.923811</td><td>false</td><td>social drinker</td><td>formal</td><td>solitary</td><td>public</td><td>single</td><td>independent</td><td>1989</td><td>technology</td><td>hard-worker</td><td>Catholic</td><td>student</td><td>green</td><td>68</td><td>low</td><td>1.72</td><td>null</td></tr><tr><td>U1009</td><td>22.159427</td><td>-100.990448</td><td>false</td><td>abstemious</td><td>formal</td><td>family</td><td>on foot</td><td>single</td><td>kids</td><td>1991</td><td>variety</td><td>thrifty-protector</td><td>Catholic</td><td>student</td><td>green</td><td>75</td><td>medium</td><td>1.78</td><td>null</td></tr><tr><td>U1010</td><td>22.190889</td><td>-100.998669</td><td>false</td><td>social drinker</td><td>no preference</td><td>friends</td><td>car owner</td><td>married</td><td>kids</td><td>1987</td><td>technology</td><td>hard-worker</td><td>none</td><td>student</td><td>green</td><td>40</td><td>medium</td><td>1.67</td><td>null</td></tr><tr><td>U1011</td><td>23.724972</td><td>-99.152856</td><td>false</td><td>abstemious</td><td>no preference</td><td>family</td><td>public</td><td>single</td><td>independent</td><td>1989</td><td>variety</td><td>hard-worker</td><td>Catholic</td><td>stud ...

# %% [markdown]
# ##Clean Data & Move to Silver Layer

# %%
from pyspark.sql.functions import col
from delta.tables import DeltaTable

# Load Bronze Table
df_bronze = spark.read.format("delta").load("dbfs:/mnt/bronze_table")

# Data Cleaning: Remove nulls, duplicates, and enforce schema
df_silver = df_bronze.dropDuplicates().filter(col("dress_preference").isNotNull())


# Save to Delta Lake (Silver Layer)
df_silver.write.format("delta").mode("overwrite").save("dbfs:/mnt/silver_table")

print("✅ Data cleaned and stored in Silver layer")
# Out:
# ✅ Data cleaned and stored in Silver layer

# %%
print("🔹 Silver Data:")
spark.read.format("delta").load("dbfs:/mnt/silver_table").show()
# Out:
# 🔹 Silver Data:
# +------+---------+-----------+------+--------------+----------------+--------+---------+--------------+-----------+----------+------------+-------------------+---------+------------+------+------+------+------+-------------+
# |userID| latitude|  longitude|smoker|   drink_level|dress_preference|ambience|transport|marital_status|      hijos|birth_year|    interest|        personality| religion|    activity| color|weight|budget|height|_rescued_data|
# +------+---------+-----------+------+--------------+----------------+--------+---------+--------------+-----------+----------+------------+-------------------+---------+------------+------+------+------+------+-------------+
# | U1004|   18.867|    -99.183| false|    abstemious|        informal|  family|   public|        single|independent|      1940|     variety|        hard-worker|     none|professional| green|    44|medium|  1.53|         null|
# | U1046|22.144415|-100.933097| false|social drinker|   no preference| friends|car owner|        single|independent|      1990|       retro|        hard-worker| Catholic|     student| black|    82|medium|  1.84|         null|
# | U1048|22.142208|-101.022785|  true|casual drinker|   no preference|       ?|   public|        single|independent|      1988|eco-friendly|  thrifty-protector|     none|     student| green|    65|medium|   1.7|         null|
# | U1126| 22.15421|-100.942233| false|casual drinker|          formal| friends|  on foot|        single|independent|      1990|  technology|        hard-worker| Catholic|     student|purple|    65|   low|  1.63|         null|
# | U1011|23.724972| -99.152856| false|    abstemious|   no preference|  family|   public|        single|independent|      1989|     variety|        hard-worker| Catholic|     student|purple|    68|medium|  1.78|         null|
# | U1024|22.154021|-100.976028|     ?|    abstemious|               ?|       ?|        ?|             ?|          ?|      1930|        none|        hard-worker|     none|           ?|yellow|    40|     ?|   1.2|         null|
# | U1067|23.752269| -99.168605| false|    abstemious|   no preference|  family|   public|        single|independent|      1987|  technology|  thrifty-protector|Christian|     student| green|    92|medium|  1.73|         null|
# | U1091|22.154677|-100.949013| false|casual drinker|   no preference|  family|car owner|        single|independent|      1989|eco-friendly|  thrifty-protector|     none|     student|   red|    40|   low|   1.7|         null|
# | U1134|22.149654| -100.99861| false|casual drinker|   no preference|  family|   public|        single|independent|      1991|     variety|        hard-worker| Catholic|     student| black|    52|medium|  1.65|         null|
# | U1116|22.156469| -100.98554| false|social drinker|          formal|  family|   public|       married|       kids|      1987|  technology|  thrifty-protector| Catholic|     student|  blue|    40|medium|  1.71|         null|
# | U1129|23.728798| -99.134047| false|casual drinker|   no preference| friends|   public|        single|independent|      1989|     variety|  thrifty-protector|     none|     student|purple|    69|   low|  1.69|         null|
# | U1055|22.143289|-100.987683| false|    abstemious|   no preference|  family|car owner|       married|  dependent|      1952|        none|        hard-worker| Catholic|professional|  blue|    70|medium|  1.66|         null|
# | U1069|19.347641| -99.130229| false|social drinker|   no preference|  family|   public|        single|independent|      1983|     variety|  thrifty-protector| Catholic|professional| black|    60|medium|  1.56|         null|
# | U1051|18.877719|  -99.22299| false|casual drinker|   no preference|  family|   public|        single|independent|      1979|     variety|  thrifty-protector|     none|professional|  blue|    74|medium|  1.76|         null|
# | U1071|22.154339|-100.975342| false|    abstemious|          formal| friends|car owner|        single|independent|      1930|        none|hunter-ostentatious|     none|     student|  blue|    40|  high|  1.73|         null|
# | U1042|18.925773| -99.219589| false|    abstemious|   no preference|  family|car owner|        single|independent|      1943|  technology|  thrifty-protector|Christian|     student|yellow|    40|  high|   1.4|         null|
# | U1054|22.150683|-100.975342| false|social drinker|          formal|  family|   public|        single|independent|      1992|  technology|  thrifty-protector| Catholic|     student|  blue|    59|medium|   1.7|         null|
# | U1104|22.149005|-100.978153|  true|social drinker|   no preference|  family|car owner|        single|independent|      1991|  technology|hunter-ostentatious| Catholic|     student|  blue|    75|medium|  1.71|         null|
# | U1035|18.839671| -99.223897|  true|casual drinker|   no preference| friends|car owner|        single|independent|      1985|     variety|hunter-ostentatious|     none|     student|   red|    69|medium|  1.75|         null|
# | U1066|18.890695| -99.157104| false|    abstemious|        informal|solitary|   public|        single|          ?|      1986|  technology|  thrifty-protector| Catholic|     student| green|    45|   low|  1.45|         null|
# +------+---------+-----------+------+--------------+----------------+--------+---------+--------------+-----------+----------+------------+-------------------+---------+------------+------+------+------+------+-------------+
# only showing top 20 rows

# %% [markdown]
# #Aggregate & Store in Gold Layer

# %%
df_silver = spark.read.format("delta").load("dbfs:/mnt/silver_table")

# Print actual column names
print(df_silver.columns)
# Out:
# ['userID', 'latitude', 'longitude', 'smoker', 'drink_level', 'dress_preference', 'ambience', 'transport', 'marital_status', 'hijos', 'birth_year', 'interest', 'personality', 'religion', 'activity', 'color', 'weight', 'budget', 'height', '_rescued_data']

# %% [markdown]
# ###Rename Columns (Fix Special Characters)

# %%
from pyspark.sql.functions import col

# Rename Columns: Replace ?, Spaces & Special Characters
new_columns = [c.encode("ascii", "ignore").decode() for c in df_silver.columns]  # Remove non-ASCII characters
new_columns = [c.replace(" ", "_").replace("(", "").replace(")", "").replace("?", "").replace("-", "_") for c in new_columns]

# Apply New Column Names
df_silver = df_silver.toDF(*new_columns)

# Print New Column Names to Verify
print(df_silver.columns)
# Out:
# ['userID', 'latitude', 'longitude', 'smoker', 'drink_level', 'dress_preference', 'ambience', 'transport', 'marital_status', 'hijos', 'birth_year', 'interest', 'personality', 'religion', 'activity', 'color', 'weight', 'budget', 'height', '_rescued_data']

# %% [markdown]
# ###Convert Columns to Numeric Types (Default they are in strings)

# %%
from pyspark.sql.functions import col
from pyspark.sql.types import IntegerType, FloatType

# Convert numeric columns from string to appropriate types
df_silver = df_silver.withColumn("birth_year", col("birth_year").cast(IntegerType())) \
                     .withColumn("weight", col("weight").cast(FloatType())) \
                     .withColumn("budget", col("budget").cast(FloatType())) \
                     .withColumn("height", col("height").cast(FloatType()))

# %%
df_silver.printSchema()
df_silver.select("birth_year", "weight", "budget", "height").show(5)
# Out:
# root
#  |-- userID: string (nullable = true)
#  |-- latitude: string (nullable = true)
#  |-- longitude: string (nullable = true)
#  |-- smoker: string (nullable = true)
#  |-- drink_level: string (nullable = true)
#  |-- dress_preference: string (nullable = true)
#  |-- ambience: string (nullable = true)
#  |-- transport: string (nullable = true)
#  |-- marital_status: string (nullable = true)
#  |-- hijos: string (nullable = true)
#  |-- birth_year: integer (nullable = true)
#  |-- interest: string (nullable = true)
#  |-- personality: string (nullable = true)
#  |-- religion: string (nullable = true)
#  |-- activity: string (nullable = true)
#  |-- color: string (nullable = true)
#  |-- weight: float (nullable = true)
#  |-- budget: float (nullable = true)
#  |-- height: float (nullable = true)
#  |-- _rescued_data: string (nullable = true)
#
# +----------+------+------+------+
# |birth_year|weight|budget|height|
# +----------+------+------+------+
# |      1940|  44.0|  null|  1.53|
# |      1990|  82.0|  null|  1.84|
# |      1988|  65.0|  null|   1.7|
# |      1990|  65.0|  null|  1.63|
# |      1989|  68.0|  null|  1.78|
# +----------+------+------+------+
# only showing top 5 rows

# %% [markdown]
# ###Save the aggregated data in the Gold layer

# %%
from pyspark.sql.functions import avg

# Load Silver Table
df_silver = spark.read.format("delta").load("dbfs:/mnt/silver_table")

# Aggregate: Find avg budget per drink_level
df_gold = df_silver.groupBy("drink_level").agg(avg("weight").alias("avg_weight"))

# Save to Delta Lake (Gold Layer)
df_gold.write.format("delta").mode("overwrite").save("dbfs:/mnt/gold_table")

print("✅ Aggregated data stored in Gold layer")
# Out:
# ✅ Aggregated data stored in Gold layer

# %% [markdown]
# ###Lets Check Result

# %%
df_gold.printSchema()
df_gold.select("drink_level", "avg_weight").show(5)
# Out:
# root
#  |-- drink_level: string (nullable = true)
#  |-- avg_weight: double (nullable = true)
#
# +--------------+-----------------+
# |   drink_level|       avg_weight|
# +--------------+-----------------+
# |    abstemious|61.96078431372549|
# |casual drinker|65.25531914893617|
# |social drinker|           68.125|
# +--------------+-----------------+

# %%
spark.read.format("delta").load("dbfs:/mnt/gold_table").show()
# Out:
# +--------------+-----------------+
# |   drink_level|       avg_weight|
# +--------------+-----------------+
# |    abstemious|61.96078431372549|
# |casual drinker|65.25531914893617|
# |social drinker|           68.125|
# +--------------+-----------------+

# %%
display(dbutils.fs.ls("/mnt"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/bronze_table/</td><td>bronze_table/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/mnt/checkpoints/</td><td>checkpoints/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/mnt/delta/</td><td>delta/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/mnt/gold_table/</td><td>gold_table/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/mnt/raw_data/</td><td>raw_data/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/mnt/schema/</td><td>schema/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/mnt/silver_table/</td><td>silver_table/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# Show Bronze Data
print("🔹 Bronze Data:")
spark.read.format("delta").load("dbfs:/mnt/bronze_table").show()
# Out:
# 🔹 Bronze Data:
# +------+---------+-----------+------+--------------+----------------+--------+---------+--------------+-----------+----------+------------+-------------------+---------+------------+------+------+------+------+-------------+
# |userID| latitude|  longitude|smoker|   drink_level|dress_preference|ambience|transport|marital_status|      hijos|birth_year|    interest|        personality| religion|    activity| color|weight|budget|height|_rescued_data|
# +------+---------+-----------+------+--------------+----------------+--------+---------+--------------+-----------+----------+------------+-------------------+---------+------------+------+------+------+------+-------------+
# | U1001|22.139997|-100.978803| false|    abstemious|        informal|  family|  on foot|        single|independent|      1989|     variety|  thrifty-protector|     none|     student| black|    69|medium|  1.77|         null|
# | U1002|22.150087|-100.983325| false|    abstemious|        informal|  family|   public|        single|independent|      1990|  technology|hunter-ostentatious| Catholic|     student|   red|    40|   low|  1.87|         null|
# | U1003|22.119847|-100.946527| false|social drinker|          formal|  family|   public|        single|independent|      1989|        none|        hard-worker| Catholic|     student|  blue|    60|   low|  1.69|         null|
# | U1004|   18.867|    -99.183| false|    abstemious|        informal|  family|   public|        single|independent|      1940|     variety|        hard-worker|     none|professional| green|    44|medium|  1.53|         null|
# | U1005|22.183477|-100.959891| false|    abstemious|   no preference|  family|   public|        single|independent|      1992|        none|  thrifty-protector| Catholic|     student| black|    65|medium|  1.69|         null|
# | U1006|    22.15|   -100.983|  true|social drinker|   no preference| friends|car owner|        single|independent|      1989|     variety|        hard-worker|     none|     student|  blue|    75|medium|   1.8|         null|
# | U1007|22.118464|-100.938256| false|casual drinker|        informal|solitary|   public|        single|independent|      1989|     variety|  thrifty-protector| Catholic|     student|purple|    60|   low|  1.59|         null|
# | U1008|22.122989|-100.923811| false|social drinker|          formal|solitary|   public|        single|independent|      1989|  technology|        hard-worker| Catholic|     student| green|    68|   low|  1.72|         null|
# | U1009|22.159427|-100.990448| false|    abstemious|          formal|  family|  on foot|        single|       kids|      1991|     variety|  thrifty-protector| Catholic|     student| green|    75|medium|  1.78|         null|
# | U1010|22.190889|-100.998669| false|social drinker|   no preference| friends|car owner|       married|       kids|      1987|  technology|        hard-worker|     none|     student| green|    40|medium|  1.67|         null|
# | U1011|23.724972| -99.152856| false|    abstemious|   no preference|  family|   public|        single|independent|      1989|     variety|        hard-worker| Catholic|     student|purple|    68|medium|  1.78|         null|
# | U1012|18.813348| -99.243697| false|casual drinker|          formal|  family|   public|        single|independent|      1988|  technology|        hard-worker| Catholic|     student|   red|    98|medium|  1.84|         null|
# | U1013|22.174624|-100.993873| false|    abstemious|   no preference| friends|   public|         widow|independent|      1982|       retro|  thrifty-protector|     none|professional|  blue|    80|medium|  1.75|         null|
# | U1014|23.751607| -99.170108| false|    abstemious|               ?| friends|   public|        single|independent|      1990|        none|        hard-worker| Catholic|     student|  blue|    53|medium|  1.69|         null|
# | U1015| 22.12676|-100.905209|  true|social drinker|        informal|  family|   public|        single|independent|      1989|  technology|  thrifty-protector| Catholic|     student| black|    87|medium|  1.67|         null|
# | U1016|22.156247|-100.977402| false|casual drinker|        informal| friends|  on foot|        single|independent|      1991|eco-friendly|  thrifty-protector| Catholic|     student| green|    70|medium|  1.67|         null|
# | U1017|18.952615| -99.201616| false|casual drinker|          formal|  family|   public|        single|          ?|      1991|       retro|hunter-ostentatious|     none|professional|orange|    79|medium|  1.79|         null|
# | U1018|22.190949|-100.917902|  true|casual drinker|          formal| friends|   public|        single|independent|      1989|  technology|  thrifty-protector|Christian|     student|  blue|    65|   low|  1.83|         null|
# | U1019|22.153385|-100.975294| false|casual drinker|   no preference|  family|   public|        single|independent|      1989|     variety|  thrifty-protector| Catholic|     student|purple|    59|medium|   1.6|         null|
# | U1020|18.878189| -99.222969| false|    abstemious|   no preference| friends|   public|        single|independent|      1982|  technology|        hard-worker| Catholic|professional|  blue|    40|medium|  1.68|         null|
# +------+---------+-----------+------+--------------+----------------+--------+---------+--------------+-----------+----------+------------+-------------------+---------+------------+------+------+------+------+-------------+
# only showing top 20 rows

# %%
# Show Silver Data
print("🔹 Silver Data:")
spark.read.format("delta").load("dbfs:/mnt/silver_table").show()
# Out:
# 🔹 Silver Data:
# +------+---------+-----------+------+--------------+----------------+--------+---------+--------------+-----------+----------+------------+-------------------+---------+------------+------+------+------+------+-------------+
# |userID| latitude|  longitude|smoker|   drink_level|dress_preference|ambience|transport|marital_status|      hijos|birth_year|    interest|        personality| religion|    activity| color|weight|budget|height|_rescued_data|
# +------+---------+-----------+------+--------------+----------------+--------+---------+--------------+-----------+----------+------------+-------------------+---------+------------+------+------+------+------+-------------+
# | U1004|   18.867|    -99.183| false|    abstemious|        informal|  family|   public|        single|independent|      1940|     variety|        hard-worker|     none|professional| green|    44|medium|  1.53|         null|
# | U1046|22.144415|-100.933097| false|social drinker|   no preference| friends|car owner|        single|independent|      1990|       retro|        hard-worker| Catholic|     student| black|    82|medium|  1.84|         null|
# | U1048|22.142208|-101.022785|  true|casual drinker|   no preference|       ?|   public|        single|independent|      1988|eco-friendly|  thrifty-protector|     none|     student| green|    65|medium|   1.7|         null|
# | U1126| 22.15421|-100.942233| false|casual drinker|          formal| friends|  on foot|        single|independent|      1990|  technology|        hard-worker| Catholic|     student|purple|    65|   low|  1.63|         null|
# | U1011|23.724972| -99.152856| false|    abstemious|   no preference|  family|   public|        single|independent|      1989|     variety|        hard-worker| Catholic|     student|purple|    68|medium|  1.78|         null|
# | U1024|22.154021|-100.976028|     ?|    abstemious|               ?|       ?|        ?|             ?|          ?|      1930|        none|        hard-worker|     none|           ?|yellow|    40|     ?|   1.2|         null|
# | U1067|23.752269| -99.168605| false|    abstemious|   no preference|  family|   public|        single|independent|      1987|  technology|  thrifty-protector|Christian|     student| green|    92|medium|  1.73|         null|
# | U1091|22.154677|-100.949013| false|casual drinker|   no preference|  family|car owner|        single|independent|      1989|eco-friendly|  thrifty-protector|     none|     student|   red|    40|   low|   1.7|         null|
# | U1134|22.149654| -100.99861| false|casual drinker|   no preference|  family|   public|        single|independent|      1991|     variety|        hard-worker| Catholic|     student| black|    52|medium|  1.65|         null|
# | U1116|22.156469| -100.98554| false|social drinker|          formal|  family|   public|       married|       kids|      1987|  technology|  thrifty-protector| Catholic|     student|  blue|    40|medium|  1.71|         null|
# | U1129|23.728798| -99.134047| false|casual drinker|   no preference| friends|   public|        single|independent|      1989|     variety|  thrifty-protector|     none|     student|purple|    69|   low|  1.69|         null|
# | U1055|22.143289|-100.987683| false|    abstemious|   no preference|  family|car owner|       married|  dependent|      1952|        none|        hard-worker| Catholic|professional|  blue|    70|medium|  1.66|         null|
# | U1069|19.347641| -99.130229| false|social drinker|   no preference|  family|   public|        single|independent|      1983|     variety|  thrifty-protector| Catholic|professional| black|    60|medium|  1.56|         null|
# | U1051|18.877719|  -99.22299| false|casual drinker|   no preference|  family|   public|        single|independent|      1979|     variety|  thrifty-protector|     none|professional|  blue|    74|medium|  1.76|         null|
# | U1071|22.154339|-100.975342| false|    abstemious|          formal| friends|car owner|        single|independent|      1930|        none|hunter-ostentatious|     none|     student|  blue|    40|  high|  1.73|         null|
# | U1042|18.925773| -99.219589| false|    abstemious|   no preference|  family|car owner|        single|independent|      1943|  technology|  thrifty-protector|Christian|     student|yellow|    40|  high|   1.4|         null|
# | U1054|22.150683|-100.975342| false|social drinker|          formal|  family|   public|        single|independent|      1992|  technology|  thrifty-protector| Catholic|     student|  blue|    59|medium|   1.7|         null|
# | U1104|22.149005|-100.978153|  true|social drinker|   no preference|  family|car owner|        single|independent|      1991|  technology|hunter-ostentatious| Catholic|     student|  blue|    75|medium|  1.71|         null|
# | U1035|18.839671| -99.223897|  true|casual drinker|   no preference| friends|car owner|        single|independent|      1985|     variety|hunter-ostentatious|     none|     student|   red|    69|medium|  1.75|         null|
# | U1066|18.890695| -99.157104| false|    abstemious|        informal|solitary|   public|        single|          ?|      1986|  technology|  thrifty-protector| Catholic|     student| green|    45|   low|  1.45|         null|
# +------+---------+-----------+------+--------------+----------------+--------+---------+--------------+-----------+----------+------------+-------------------+---------+------------+------+------+------+------+-------------+
# only showing top 20 rows

# %%
# Show Gold Data
print("🔹 Gold Data:")
spark.read.format("delta").load("dbfs:/mnt/gold_table").show()
# Out:
# 🔹 Gold Data:
# +--------------+-----------------+
# |   drink_level|       avg_weight|
# +--------------+-----------------+
# |    abstemious|61.96078431372549|
# |casual drinker|65.25531914893617|
# |social drinker|           68.125|
# +--------------+-----------------+
